# %% [markdown]
# ## DOE ARM SGP 30ECOR Analysis
# ### Latent heat flux analysis as a function of surface conditions (vegetation type, etc.) reported in ARM Preventative Maintenance (PM) reports
#
# ##### Written by Sid Gupta (sid.gupta@anl.gov) - last updated September, 2025
# - Reviewed by Adam Theisen for upload to ARM-FLUX-VEG repository.
#
# The authors acknowledge the contributions of the site operations staff for their dedicated efforts in manually collecting and curating vegetation information. These measurements were integral to the development and production of this data product.
#
# #### Introduction
#
# This notebook deals with Eddy Correlation Flux Measurement System (ECOR) data from the ARM Southern Great Plains (SGP) facility sites. Preventative Maintenance (PM) reports provide site operator responses to preset questions about vegetation and surface conditions. These responses can supplement the ECOR measurements to provide ground truth. These responses can be subjective, and thus they are provided here in place of an ARM datastream.
#
# Data from old PM reports until 2020 were compiled into a single file. The notebook describes how data from the biweekly PM reports can be used along with the ECOR datastream. Please see the instrument webpage for the Eddy Correlation Flux Measurement System (ECOR) (https://www.arm.gov/capabilities/instruments/ecor). In October 2019, the ECOR systems at SGP were upgraded with newer-model instruments, including the addition of a microprocessor allowing both uncorrected and corrected fluxes in a single datastream, ECORSF. A separate notebook is provided for using the ECORSF datastream.
#
# Uncorrected turbulent fluxes are available in the 30ecor datastream. It is recommended that routine ECOR corrections are applied to the data prior to use, and corrected fluxes are available in the 30qcecor VAP. This notebook deals with pre-2019 ECOR data (30ECOR) and surface/vegetation conditions. In the 30ECOR datastream, there are known issues with the CO$_2$ flux measurements and this notebook concerns only the latent heat flux.
#
# Notes:
# - S4, S5, and S6 were only deployed temporarily for the AWAKEN field campaign - there are not too many PM reports for these sites after the campaign.
# - PM reports are provided biweekly, and it is assumed surface conditions did not vary considerably over the two week period. With this assumption, ECOR data from the preceding two weeks can be associated with the PM report. Thus, one can analyze flux measurements as a function of vegetation type, condition, color, etc.
# - This notebook helps identify sites with most PM reports; commonly reported crop types and surface conditions, etc. The notebook provides examples for plots of trends in CO$_2$ or latent heat fluxes as a function of the crop types and vegetation/soil conditions.
#
# #### Notebook Contents
# - Find most frequently reported vegetation conditions
# - Calculate flux by vegetation type
# - Retrieve ECOR data for the timings associated with these conditions
# - Find variability in flux data based on variable conditions within these timings

# %%
import act
import xarray as xr
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
import glob

# %% [markdown]
# ## NEED TO FIX THE VARIABLES THAT ARE MESSED UP (LIKE ECVT1 FOREST COVERED, ECVT2)

# %% [markdown]
# ### Load PM reports data

# %%
sfccond=pd.read_excel('SGP_Surface_Conditions.xlsx')
sfccond.keys()
# Out:
# Index(['Timeon', 'Sitename', 'Date', 'Name', 'tvlA', 'tvlB', 'tvlC', 'tvlD',
#        'tvlE', 'hinside', 'houtside', 'ecunan', 'pasrg', 'ecvt2', 'ecvt1',
#        'mbs', 'wwh', 'wwhlst', 'rcrp', 'rctyp', 'rctyp1', 'ecvcon', 'ecsoil',
#        'ecmoist', 'echt', 'vhifmos', 'vhofmos', 'Comments'],
#       dtype='object')

# %% [markdown]
# Variable long names (along with most common responses):
#
# - Name - Technician name
# - tvlA - Type of vegetation (Mostly clumped grass, Mostly uniform grass)
# - tvlB - Type of vegetation (Derived from grazed grasslands, Native prairie)
# - tvlC - Vegetation condition ('Brown due to freezing conditions', 'Lush green, unwilted', 'Green w/brown patches because of hot, dry weather', 'Mostly brown due to hot, dry weather','Fully green but noticeably wilted')
# - tvlD - Surface soil conditions ('Dry and dusty', 'Moist but not muddy', 'Muddy or standing water')
# - tvlE - Moisture on vegetation (or soil if no vegetation) ('Dry', 'Slightly wet because of rain or dew', 'Mostly wet because of rain or dew')
# - hinside - Approximate height of vegetation inside fence
# - houtside - Approximate height of vegetation outside but near fence
#
#
# Only for sites with Eddy Correlation (EC) stations:
# - ecunan - Unanticipated vegetation condition (mostly No)
# - pasrg - Pasture or rangeland (No: 3943, Yes: 922)
# - ecvt2 - Type of vegetation ('Derived from grazed grasslands', 'Native prairie', 'Forest Covered')
# - ecvt1 - Type of vegetation ('Mostly clumped grass', 'Mostly uniform grass', 'Forest Covered', 'Woods')
# - mbs - Mostly bare soil (Yes, No)
# - wwh - Winter wheat (Yes, No)
# - wwhlst - Winter wheat condition ('Green, ground covered','Partial soil coverage because plants are small','Stubble after harvest','Stubble mostly covered with green weeds after harvest','Yellow but unharvested')
# - rcrp - Row crops (Yes, No)
# - rctyp - Row crop type ('Alfalfa', 'Soybeans', 'Corn', 'Other Row Crop (see comments)','Sorghum', 'Milo')
# - rctyp1 - Row crop type ('Green, ground covered', 'Only debris left after harvest','Yellow but unharvested', 'Partial soil coverage because plants small')
# - ecvcon - Vegetation condition ('Lush green, unwilted', 'Brown due to freezing conditions','All or mostly bare soil', 'Mostly brown due to hot, dry weather','Green with brown patches because of hot, dry weather','Fully green but noticeably wilted')
# - ecsoil - Surface soil conditions ('Dry and dusty', 'Moist but not muddy', 'Muddy or standing water')
# - ecmoist - Moisture on vegetation or soil ('Dry', 'Slightly wet because of rain or dew', 'Mostly wet because of rain or dew', '0-25% snow covered')
# - echt - Approximate height of vegetation
#
# Only at extended facilities with EBBR stations
#
# - vhifmos - Vegetation inside fence is mostly (Grassy, Broadleaf)
# - vhofmos - Vegetation outside fence is mostly (Grassy, Broadleaf)

# %% [markdown]
# #### Identify the most commonly reported sites where crops are reported and identify crop type

# %%
# sfccond['Sitename'].value_counts() # Identify most commonly reported sites

sfccond[['rctyp','Sitename']].value_counts()[0:20]
# Out:
# rctyp                          Sitename
# Alfalfa                        E6 Towanda      178
#                                E14 CF          119
# Soybeans                       E3 LeRoy        107
#                                E33 Newkirk     104
# Alfalfa                        E10 Tyro         65
# Sorghum                        E5 Halstead      64
# Soybeans                       E31 Anthony      55
# Corn                           E31 Anthony      55
#                                E3 LeRoy         53
#                                E33 Newkirk      42
# Soybeans                       E39 Morrison     39
# Milo                           E31 Anthony      37
# Soybeans                       E5 Halstead      30
# Corn                           E14 CF           29
# Other Row Crop (see comments)  E3 LeRoy         26
#                                E1 Larned        18
#                                E31 Anthony      12
# Corn                           E5 Halstead      12
# Other Row Crop (see comments)  E5 Halstead      10
# Forrest covered                E21 Okmulgee      8
# Name: count, dtype: int64

# %%
# We can define a subset of the data when the 'row crop' field was set to 'Yes', indicating the presence of crops
site_conditions_all=sfccond[sfccond['rcrp']=='Yes']

site_conditions_all['Sitename'].value_counts()[0:6]
# Out:
# Sitename
# E3 LeRoy       200
# E6 Towanda     178
# E31 Anthony    163
# E14 CF         151
# E33 Newkirk    143
# E5 Halstead    112
# Name: count, dtype: int64

# %%
# site_conditions=sfccond[(sfccond['Sitename']=='E3 LeRoy') & (sfccond['rcrp']=='Yes')]

# %% [markdown]
# ### Download 30ECOR data for two weeks leading up to each PM report

# %%
# Data are downloaded using the DOE ACT software package (see https://arm-doe.github.io/ACT/API/generated/act.discovery.download_arm_data.html)

# Set your ARM Live data username and password (see instructions on ACT link above)
username = ''
token = ''

# %%
# Mention a single site from the list
# Downloading and processing multiple sites together is not recommended due to download time and file volumes
sites = ['E3 LeRoy'] # E3 LeRoy, E6 Towanda, E5 Halstead

# Number of days to extend back from report date; using 13 since PM reports are biweekly
interval=13

for site in sites:

    if site[2]==' ':
        sitename=site[0:2]
    else:
        sitename=site[0:3]
    
    print(sitename)
    datastream = 'sgp30ecor'+sitename+'.b1'
    site_conditions = site_conditions_all[site_conditions_all['Sitename']==site]
        
    for k in range(0,len(site_conditions)): # len(site_conditions) - Pull in flux data for up to <interval> days before report
        startdate=(pd.to_datetime(site_conditions.Date.values[k])-pd.Timedelta(interval,'d')).strftime('%Y%m%d')
        enddate=pd.to_datetime(site_conditions.time.values[k]).strftime('%Y%m%d')

    # Check if file is already downloaded, if not, download the data
        
        if len(glob.glob('sgp30ecor'+sitename+'.b1/*'+startdate+'*'))>0 or \
        len(glob.glob('sgp30ecor'+sitename+'.b1/*'+enddate+'*'))>0:
            print('sgp30ecor'+sitename+'.b1 for start ('+startdate+') or end ('+enddate+') found, not attempting to download this 2-week period')
        else:        
            ecor_files = act.discovery.download_arm_data(username, token, datastream, startdate, enddate)
# Out:
# E3 LeRoy
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# sgp30ecorE3.b1 for start (20040311) or end (20040324) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040325) or end (20040407) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040408) or end (20040421) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040520) or end (20040602) found, not attempting to download this 2-week period
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# sgp30ecorE3.b1 for start (20040617) or end (20040630) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040701) or end (20040714) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040715) or end (20040728) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040729) or end (20040811) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040812) or end (20040825) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040826) or end (20040908) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040910) or end (20040923) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20040923) or end (20041006) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20041007) or end (20041020) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20041021) or end (20041103) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20041104) or end (20041117) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20041118) or end (20041201) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20041202) or end (20041215) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20041216) or end (20041229) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20041230) or end (20050112) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050113) or end (20050126) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050127) or end (20050209) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050210) or end (20050223) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050224) or end (20050309) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050407) or end (20050420) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050421) or end (20050504) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050506) or end (20050519) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050520) or end (20050602) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050603) or end (20050616) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050616) or end (20050629) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050630) or end (20050713) found, not attempting to download this 2-week period
# [DOWNLOADING] sgp30ecorE3.b1.20050715.163000.cdf
# [DOWNLOADING] sgp30ecorE3.b1.20050716.000000.cdf
# [DOWNLOADING] sgp30ecorE3.b1.20050717.000000.cdf
# [DOWNLOADING] sgp30ecorE3.b1.20050718.000000.cdf
# [DOWNLOADING] sgp30ecorE3.b1.20050719.000000.cdf
#
# If you use these data to prepare a publication, please cite:
#
# Sullivan, R., Billesbach, D., Keeler, E., Ermold, B., & Pal, S. Eddy Correlation
# Flux Measurement System (30ECOR), 2005-07-14 to 2005-07-27, Southern Great
# Plains (SGP), LeRoy, KS (Extended) (E3). Atmospheric Radiation Measurement (ARM)
# User Facility. https://doi.org/10.5439/1025039
#
# sgp30ecorE3.b1 for start (20050728) or end (20050810) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050811) or end (20050824) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050825) or end (20050907) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050908) or end (20050921) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20050923) or end (20051006) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20051006) or end (20051019) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20051020) or end (20051102) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20051103) or end (20051116) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20051117) or end (20051130) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20051201) or end (20051214) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20051215) or end (20051228) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20051229) or end (20060111) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20060113) or end (20060126) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20060126) or end (20060208) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20060727) or end (20060809) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20060810) or end (20060823) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20060824) or end (20060906) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20060907) or end (20060920) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20060921) or end (20061004) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20061005) or end (20061018) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20061019) or end (20061101) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20061102) or end (20061115) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20061116) or end (20061129) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20061130) or end (20061213) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20061214) or end (20061227) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20061228) or end (20070110) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070111) or end (20070124) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070208) or end (20070221) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070221) or end (20070306) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070308) or end (20070321) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070322) or end (20070404) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070503) or end (20070516) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070517) or end (20070530) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070531) or end (20070613) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070613) or end (20070626) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070628) or end (20070711) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070713) or end (20070726) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070726) or end (20070808) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070809) or end (20070822) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070823) or end (20070905) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070906) or end (20070919) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20070920) or end (20071003) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20071004) or end (20071017) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20071018) or end (20071031) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20071018) or end (20071031) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20071101) or end (20071114) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20071227) or end (20080109) found, not attempting to download this 2-week period
# [DOWNLOADING] sgp30ecorE3.b1.20071204.160000.cdf
# [DOWNLOADING] sgp30ecorE3.b1.20071205.000000.cdf
# [DOWNLOADING] sgp30ecorE3.b1.20071206.000000.cdf
# [DOWNLOADING] sgp30ecorE3.b1.20071207.130000.cdf
#
# If you use these data to prepare a publication, please cite:
#
# Sullivan, R., Billesbach, D., Keeler, E., Ermold, B., & Pal, S. Eddy Correlation
# Flux Measurement System (30ECOR), 2007-11-29 to 2007-12-12, Southern Great
# Plains (SGP), LeRoy, KS (Extended) (E3). Atmospheric Radiation Measurement (ARM)
# User Facility. https://doi.org/10.5439/1025039
#
# sgp30ecorE3.b1 for start (20080110) or end (20080123) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20080124) or end (20080206) found, not attempting to download this 2-week period
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# sgp30ecorE3.b1 for start (20080320) or end (20080402) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20080403) or end (20080416) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20080710) or end (20080723) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20080724) or end (20080806) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20080807) or end (20080820) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20080821) or end (20080903) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20080904) or end (20080917) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20080917) or end (20080930) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20081002) or end (20081015) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20081016) or end (20081029) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20081210) or end (20081223) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20081225) or end (20090107) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090108) or end (20090121) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090123) or end (20090205) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090205) or end (20090218) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090306) or end (20090319) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090403) or end (20090416) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090417) or end (20090430) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090501) or end (20090514) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090514) or end (20090527) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090529) or end (20090611) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090611) or end (20090624) found, not attempting to download this 2-week period
# sgp30ecorE3.b1 for start (20090625) or end (20090708) found, not attempting to download this 2-week period
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# No files returned or url status error.
# Check datastream name, start, and end date.
#
# sgp30ecorE3.b1 for start (20090806) or end (20090819) found, not attempting to download this 2-week period

# %% [markdown]
# ### Concatenate biweekly data for each PM report. This part of the code will take some time since some sites can often have PM reports spanning multiple years. Please run this cell for a single site at one time.
# #### Retrieve daily data files (with 30-min time resolution)
# #### Apply Quality Control Flag
# #### Apply Wind Direction check
# - ECOR stations are located over a variety of vegetation types including cropland, grassland, and forest, depending on site and prevailing wind direction. Users should be aware of the surface type representation when using the turbulent flux measurements from ECOR and EBBR. More information about site-specific vegetation type can be found in the ECOR instrument handbook (https://www.arm.gov/publications/tech_reports/handbooks/ecor_handbook.pdf). Wind directions that are not listed are directions for which the fetch is insufficient, and therefore, for which the ECOR flux data are suspect and have to be discarded.
# - Create variables (co2_ or latent_flux_site_date) for each date.
# - Concatenate these variables into a single variable per PM report (i.e., concatenate 2 weeks worth of data into one file for each PM report)
# - The data are reported every 30 minutes, so each date should have up to 48 measurements. Some of these are removed due to the QC flag or wind direction.
#
# #### Output:
# - variable_site_date: Daily measurements for a specific site for a specific date
# - variable_biweekly_site_date: Daily measurements for a specific site for a two-week period ending in the date of each PM report
# - variable: Average value of the biweekly measurements; added to the dataframe associated to each site for box plots
# The daily measurement variables are useful for the time series plots further below. The average values are useful for box-whisker plots below. Users can save the site-specific dataframes to create box-whisker plots later without running the entire notebook. Doing so for daily measurements would create a large number of additional files and is not done currently.

# %%
sites = ['E3 LeRoy'] # E3 LeRoy, E6 Towanda, E5 Halstead  

# Number of days to extend back from report date; using 13 since PM reports are biweekly
interval=13

for site in sites:

    if site[2]==' ':
        sitename=site[0:2]
    else:
        sitename=site[0:3]

    print(sitename)
    datastream = 'sgp30ecor'+sitename+'.b1'
    site_conditions = site_conditions_all[site_conditions_all['Sitename']==site]
        
    for k in range(0,len(site_conditions)): # len(site_conditions) - Pull in flux data for up to <interval> days before report
        startdate=(pd.to_datetime(site_conditions.Date.values[k])-pd.Timedelta(interval,'d')).strftime('%Y%m%d')
        enddate=pd.to_datetime(site_conditions.Date.values[k]).strftime('%Y%m%d')

        files=[]
        dates=[]        

        # Get data for each date pulled for a report
        for jj in range(interval,-1,-1):
            date=(pd.to_datetime(site_conditions.Date.values[k])-pd.Timedelta(jj,'d')).strftime('%Y%m%d')
            file = glob.glob('sgp30ecor'+sitename+'.b1/*'+date+'*')

            
            if len(file)>0:            
                fluxdata=xr.open_dataset(file[0])

                # Apply QC flag
                latent_flux_1=fluxdata.lv_e.where(fluxdata.qc_lv_e==0)
#                 co2_flux_1=fluxdata.co2_flux.where(fluxdata.flag_co2_flux<2)

                # Apply wind direction dependency 
                wdir=fluxdata.wind_dir
                
                if sitename=='E3':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or((wdir>0) & (wdir<48),(wdir>132) & (wdir<260))).dropna('time')
                elif sitename=='E6':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where((wdir>0) & (wdir<360)).dropna('time')
                elif sitename=='E5':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or((wdir>80) & (wdir<154),(wdir>154) & (wdir<260))).dropna('time')                    
                elif sitename=='E39':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or(np.logical_or((wdir>0) & (wdir<80),(wdir>100) & (wdir<260)),(wdir>280) & (wdir<360))).dropna('time')
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where(np.logical_or(np.logical_or((wdir>0) & (wdir<80),(wdir>100) & (wdir<260)),(wdir>280) & (wdir<360))).dropna('time')
                elif sitename=='E37':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or((wdir>135) & (wdir<260),(wdir>280) & (wdir<310))).dropna('time')
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where(np.logical_or((wdir>135) & (wdir<260),(wdir>280) & (wdir<310))).dropna('time')
                elif sitename=='E33':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or((wdir>100) & (wdir<300),(wdir>40) & (wdir<80))).dropna('time')
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where(np.logical_or((wdir>100) & (wdir<300),(wdir>40) & (wdir<80))).dropna('time')
                elif sitename=='E31':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or((wdir>100) & (wdir<200),(wdir>30) & (wdir<80))).dropna('time')
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where(np.logical_or((wdir>100) & (wdir<200),(wdir>20) & (wdir<80))).dropna('time')            
                elif sitename=='E14':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or(np.logical_or((wdir>0) & (wdir<85),(wdir>129) & (wdir<265)),(wdir>352) & (wdir<360))).dropna('time')
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where(np.logical_or(np.logical_or((wdir>0) & (wdir<85),(wdir>129) & (wdir<265)),(wdir>352) & (wdir<360))).dropna('time')
                elif sitename=='E41':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or(np.logical_or((wdir>0) & (wdir<80),(wdir>100) & (wdir<260)),(wdir>280) & (wdir<360))).dropna('time')
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where(np.logical_or(np.logical_or((wdir>0) & (wdir<80),(wdir>100) & (wdir<260)),(wdir>280) & (wdir<360))).dropna('time')
                elif sitename=='E13':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or(np.logical_or((wdir>0) & (wdir<52),(wdir>142) & (wdir<194)),(wdir>328) & (wdir<360))).dropna('time')
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where(np.logical_or(np.logical_or((wdir>0) & (wdir<52),(wdir>142) & (wdir<194)),(wdir>328) & (wdir<360))).dropna('time')            
                elif sitename=='E15':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where((wdir>133) & (wdir<360)).dropna('time')
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where((wdir>133) & (wdir<360)).dropna('time')                    
                elif sitename=='E1':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or((wdir>0) & (wdir<53),(wdir>120) & (wdir<360))).dropna('time')                                           
                    globals()['co2_{}_{}'.format(sitename,date)]=co2_1.where(np.logical_or((wdir>0) & (wdir<53),(wdir>120) & (wdir<360))).dropna('time')                                                                   
                elif sitename=='E10':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where((wdir>0) & (wdir<360)).dropna('time')                    
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where((wdir>0) & (wdir<360)).dropna('time')                                            
                elif sitename=='E11':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where((wdir>0) & (wdir<360)).dropna('time')                                        
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where((wdir>0) & (wdir<360)).dropna('time')                                        
                elif sitename=='E16':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where(np.logical_or((wdir>134) & (wdir<269),(wdir>334) & (wdir<360))).dropna('time')                                           
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where(np.logical_or((wdir>134) & (wdir<269),(wdir>334) & (wdir<360))).dropna('time')                                           
                elif sitename=='E24':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where((wdir>80) & (wdir<280)).dropna('time')                                               
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where((wdir>80) & (wdir<280)).dropna('time')                                               
                elif sitename=='E32':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where((wdir>0) & (wdir<360)).dropna('time')                                                                       
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where((wdir>0) & (wdir<360)).dropna('time')                                                                       
                elif sitename=='E38':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where((wdir>150) & (wdir<260)).dropna('time')                                                                                           
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where((wdir>150) & (wdir<260)).dropna('time')                                                                                           
                elif sitename=='E21':
                    globals()['latent_flux_{}_{}'.format(sitename,date)]=latent_flux_1.where((wdir>30) & (wdir<360)).dropna('time')                        
                    globals()['co2_flux_{}_{}'.format(sitename,date)]=co2_flux_1.where((wdir>30) & (wdir<360)).dropna('time')                    

        # Create a single concatenated variable for each PM report with data from all corresponding dates
                dates.append(date)
                files.append(glob.glob('sgpecorsf'+sitename+'.b1/*'+date+'*'))

        if len(files)>0:
            for kk in range(0,len(files)):
                if kk==0:
                    globals()['latent_flux_biweekly_{}_{}'.format(sitename,enddate)]=globals()['latent_flux_{}_{}'.format(sitename,dates[kk])]
                    # globals()['co2_flux_biweekly_{}_{}'.format(sitename,enddate)]=globals()['co2_flux_{}_{}'.format(sitename,dates[kk])]
                    print('{} has {} data points'.format(dates[kk],len(globals()['latent_flux_{}_{}'.format(sitename,dates[kk])])))
                else:
                    globals()['latent_flux_biweekly_{}_{}'.format(sitename,enddate)]=\
                    xr.concat([globals()['latent_flux_biweekly_{}_{}'.format(sitename,enddate)],\
                              globals()['latent_flux_{}_{}'.format(sitename,dates[kk])]],'time')
                    # globals()['co2_flux_biweekly_{}_{}'.format(sitename,enddate)]=\
                    # xr.concat([globals()['co2_flux_biweekly_{}_{}'.format(sitename,enddate)],\
                    #           globals()['co2_flux_{}_{}'.format(sitename,dates[kk])]],'time')
                    print('{} has {} data points'.format(dates[kk],len(globals()['latent_flux_{}_{}'.format(sitename,dates[kk])])))
            print('Flux files created for {}-{}'.format(sitename,enddate))  
        else:
            print('No data were found for {}-{}'.format(sitename,enddate))
# Out:
# E3 LeRoy
# No data were found for E3-19990623
# No data were found for E3-19990707
# No data were found for E3-19990721
# No data were found for E3-19990804
# No data were found for E3-19970402
# No data were found for E3-19970430
# No data were found for E3-19961002
# No data were found for E3-19961223
# No data were found for E3-19990818
# No data were found for E3-19990901
# No data were found for E3-19990915
# No data were found for E3-19990929
# No data were found for E3-19991013
# No data were found for E3-19991027
# No data were found for E3-19991109
# No data were found for E3-19991123
# No data were found for E3-19991208
# No data were found for E3-20000524
# No data were found for E3-20000607
# No data were found for E3-20000621
# No data were found for E3-20000706
# No data were found for E3-20000719
# No data were found for E3-20000802
# No data were found for E3-20000816
# No data were found for E3-20000830
# No data were found for E3-20000913
# No data were found for E3-20000927
# No data were found for E3-20001011
# No data were found for E3-20001025
# No data were found for E3-20001108
# No data were found for E3-20001121
# No data were found for E3-20001220
# No data were found for E3-20010103
# No data were found for E3-20010117
# No data were found for E3-20010131
# No data were found for E3-20010214
# No data were found for E3-20010228
# No data were found for E3-20010314
# No data were found for E3-20010328
# No data were found for E3-20010411
# No data were found for E3-20010509
# No data were found for E3-20010523
# No data were found for E3-20010606
# No data were found for E3-20010620
# No data were found for E3-20010704
# No data were found for E3-20010718
# No data were found for E3-20010801
# No data were found for E3-20010815
# No data were found for E3-20010829
# No data were found for E3-20010912
# No data were found for E3-20010926
# No data were found for E3-20011010
# No data were found for E3-20011024
# No data were found for E3-20011107
# No data were found for E3-20011120
# No data were found for E3-20011205
# No data were found for E3-20011219
# No data were found for E3-20020103
# No data were found for E3-20020116
# No data were found for E3-20020213
# No data were found for E3-20020227
# No data were found for E3-20020313
# No data were found for E3-20020327
# No data were found for E3-20020410
# No data were found for E3-20020424
# No data were found for E3-20020508
# No data were found for E3-20020522
# No data were found for E3-20020605
# No data were found for E3-20020619
# No data were found for E3-20020702
# No data were found for E3-20020717
# No data were found for E3-20020731
# No data were found for E3-20020814
# No data were found for E3-20020828
# No data were found for E3-20020910
# No data were found for E3-20020925
# No data were found for E3-20021010
# No data were found for E3-20021023
# No data were found for E3-20021106
# No data were found for E3-20021120
# No data were found for E3-20021204
# No data were found for E3-20021230
# No data were found for E3-20030115
# No data were found for E3-20030212
# No data were found for E3-20030312
# No data were found for E3-20031230
# No data were found for E3-20040114
# No data were found for E3-20040211
# No data were found for E3-20040224
# 20040311 has 5 data points
# 20040312 has 36 data points
# 20040313 has 48 data points
# 20040314 has 19 data points
# 20040315 has 25 data points
# 20040316 has 12 data points
# 20040317 has 47 data points
# 20040318 has 21 data points
# 20040319 has 21 data points
# 20040320 has 43 data points
# 20040321 has 43 data points
# 20040322 has 29 data points
# 20040323 has 48 data points
# 20040324 has 46 data points
# Flux files created for E3-20040324
# 20040325 has 46 data points
# 20040326 has 48 data points
# 20040327 has 47 data points
# 20040328 has 6 data points
# 20040329 has 19 data points
# 20040330 has 0 data points
# 20040331 has 28 data points
# 20040401 has 19 data points
# 20040402 has 23 data points
# 20040403 has 12 data points
# 20040404 has 19 data points
# 20040405 has 31 data points
# 20040406 has 48 data points
# 20040407 has 17 data points
# Flux files created for E3-20040407
# 20040408 has 32 data points
# 20040409 has 22 data points
# 20040410 has 41 data points
# 20040411 has 19 data points
# 20040412 has 18 data points
# 20040413 has 17 data points
# 20040414 has 38 data points
# 20040415 has 48 data points
# 20040416 has 48 data points
# 20040417 has 48 data points
# 20040418 has 47 data points
# 20040419 has 37 data points
# 20040420 has 37 data points
# 20040421 has 19 data points
# Flux files created for E3-20040421
# 20040520 has 48 data points
# 20040521 has 48 data points
# 20040522 has 48 data points
# 20040523 has 30 data points
# 20040524 has 40 data points
# 20040525 has 5 data points
# Flux files created for E3-20040602
# No data were found for E3-20040616
# 20040617 has 0 data points
# 20040618 has 0 data points
# 20040619 has 0 data points
# 20040620 has 0 data points
# 20040621 has 0 data points
# 20040622 has 0 data points
# 20040623 has 0 data points
# 20040624 has 0 data points
# 20040625 has 0 data points
# 20040626 has 0 data points
# 20040627 has 0 data points
# 20040628 has 0 data points
# 20040629 has 0 data points
# 20040630 has 0 data points
# Flux files created for E3-20040630
# 20040701 has 26 data points
# 20040702 has 25 data points
# 20040703 has 2 data points
# 20040704 has 33 data points
# 20040705 has 33 data points
# 20040706 has 23 data points
# 20040707 has 26 data points
# 20040708 has 39 data points
# 20040709 has 37 data points
# 20040710 has 47 data points
# 20040711 has 48 data points
# 20040712 has 48 data points
# 20040713 has 47 data points
# 20040714 has 23 data points
# Flux files created for E3-20040714
# 20040715 has 18 data points
# 20040716 has 18 data points
# 20040717 has 33 data points
# 20040718 has 34 data points
# 20040719 has 40 data points
# 20040720 has 47 data points
# 20040721 has 48 data points
# 20040722 has 40 data points
# 20040723 has 30 data points
# 20040724 has 11 data points
# 20040725 has 48 data points
# 20040726 has 30 data points
# 20040727 has 35 data points
# 20040728 has 45 data points
# Flux files created for E3-20040728
# 20040729 has 15 data points
# 20040730 has 13 data points
# 20040731 has 37 data points
# 20040801 has 48 data points
# 20040802 has 48 data points
# 20040803 has 44 data points
# 20040804 has 34 data points
# 20040805 has 16 data points
# 20040806 has 9 data points
# 20040807 has 27 data points
# 20040808 has 44 data points
# 20040809 has 22 data points
# 20040810 has 29 data points
# 20040811 has 19 data points
# Flux files created for E3-20040811
# 20040812 has 21 data points
# 20040813 has 27 data points
# 20040814 has 36 data points
# 20040815 has 20 data points
# 20040816 has 37 data points
# 20040817 has 46 data points
# 20040818 has 46 data points
# 20040819 has 27 data points
# 20040820 has 12 data points
# 20040821 has 17 data points
# 20040822 has 30 data points
# 20040823 has 45 data points
# 20040824 has 31 data points
# 20040825 has 48 data points
# Flux files created for E3-20040825
# 20040826 has 48 data points
# 20040827 has 48 data points
# 20040828 has 15 data points
# 20040829 has 25 data points
# 20040830 has 38 data points
# 20040831 has 36 data points
# 20040901 has 27 data points
# 20040902 has 32 data points
# 20040903 has 46 data points
# 20040904 has 44 data points
# 20040905 has 48 data points
# 20040906 has 10 data points
# 20040907 has 42 data points
# 20040908 has 28 data points
# Flux files created for E3-20040908
# 20040910 has 34 data points
# 20040911 has 37 data points
# 20040912 has 37 data points
# 20040913 has 48 data points
# 20040914 has 48 data points
# 20040915 has 33 data points
# 20040916 has 16 data points
# 20040917 has 20 data points
# 20040918 has 22 data points
# 20040919 has 48 data points
# 20040920 has 46 data points
# 20040921 has 48 data points
# 20040922 has 45 data points
# 20040923 has 33 data points
# Flux files created for E3-20040923
# 20040923 has 33 data points
# 20040924 has 18 data points
# 20040925 has 19 data points
# 20040926 has 30 data points
# 20040927 has 27 data points
# 20040928 has 32 data points
# 20040929 has 24 data points
# 20040930 has 35 data points
# 20041001 has 42 data points
# 20041002 has 16 data points
# 20041003 has 38 data points
# 20041004 has 24 data points
# 20041005 has 12 data points
# 20041006 has 24 data points
# Flux files created for E3-20041006
# 20041007 has 17 data points
# 20041008 has 33 data points
# 20041009 has 23 data points
# 20041010 has 7 data points
# 20041011 has 12 data points
# 20041012 has 11 data points
# 20041013 has 4 data points
# 20041014 has 0 data points
# 20041015 has 10 data points
# 20041016 has 1 data points
# 20041017 has 31 data points
# 20041018 has 6 data points
# 20041019 has 32 data points
# 20041020 has 0 data points
# Flux files created for E3-20041020
# 20041021 has 12 data points
# 20041022 has 41 data points
# 20041023 has 22 data points
# 20041024 has 42 data points
# 20041025 has 35 data points
# 20041026 has 32 data points
# 20041027 has 7 data points
# 20041028 has 32 data points
# 20041029 has 48 data points
# 20041030 has 6 data points
# 20041031 has 33 data points
# 20041101 has 11 data points
# 20041102 has 40 data points
# 20041103 has 24 data points
# Flux files created for E3-20041103
# 20041104 has 0 data points
# 20041105 has 30 data points
# 20041106 has 32 data points
# 20041107 has 35 data points
# 20041108 has 23 data points
# 20041109 has 41 data points
# 20041110 has 38 data points
# 20041111 has 35 data points
# 20041112 has 38 data points
# 20041113 has 5 data points
# 20041114 has 11 data points
# 20041115 has 20 data points
# 20041116 has 44 data points
# 20041117 has 42 data points
# Flux files created for E3-20041117
# 20041118 has 8 data points
# 20041119 has 17 data points
# 20041120 has 19 data points
# 20041121 has 36 data points
# 20041122 has 27 data points
# 20041123 has 28 data points
# 20041124 has 0 data points
# 20041125 has 32 data points
# 20041126 has 45 data points
# 20041127 has 1 data points
# 20041128 has 6 data points
# 20041129 has 18 data points
# 20041130 has 10 data points
# 20041201 has 43 data points
# Flux files created for E3-20041201
# 20041202 has 8 data points
# 20041203 has 16 data points
# 20041204 has 42 data points
# 20041205 has 27 data points
# 20041206 has 22 data points
# 20041207 has 4 data points
# 20041208 has 41 data points
# 20041209 has 26 data points
# 20041210 has 0 data points
# 20041211 has 15 data points
# 20041212 has 24 data points
# 20041213 has 0 data points
# 20041214 has 13 data points
# 20041215 has 48 data points
# Flux files created for E3-20041215
# 20041216 has 30 data points
# 20041217 has 23 data points
# 20041218 has 14 data points
# 20041219 has 16 data points
# 20041220 has 28 data points
# 20041221 has 5 data points
# 20041222 has 47 data points
# 20041223 has 39 data points
# 20041224 has 23 data points
# 20041225 has 48 data points
# 20041226 has 25 data points
# 20041227 has 26 data points
# 20041228 has 48 data points
# 20041229 has 12 data points
# Flux files created for E3-20041229
# 20041230 has 48 data points
# 20041231 has 32 data points
# 20050101 has 31 data points
# 20050102 has 19 data points
# 20050103 has 6 data points
# 20050104 has 17 data points
# 20050105 has 0 data points
# 20050106 has 0 data points
# 20050107 has 0 data points
# 20050108 has 0 data points
# 20050109 has 19 data points
# 20050110 has 13 data points
# 20050111 has 0 data points
# 20050112 has 0 data points
# Flux files created for E3-20050112
# 20050113 has 0 data points
# 20050114 has 0 data points
# 20050115 has 0 data points
# 20050116 has 0 data points
# 20050117 has 0 data points
# 20050118 has 0 data points
# 20050119 has 0 data points
# 20050120 has 0 data points
# 20050121 has 0 data points
# 20050122 has 0 data points
# 20050123 has 0 data points
# 20050124 has 0 data points
# 20050125 has 0 data points
# 20050126 has 0 data points
# Flux files created for E3-20050126
# 20050127 has 12 data points
# 20050128 has 0 data points
# 20050129 has 8 data points
# 20050130 has 14 data points
# 20050131 has 17 data points
# 20050201 has 21 data points
# 20050202 has 40 data points
# 20050203 has 30 data points
# 20050204 has 38 data points
# 20050205 has 48 data points
# 20050206 has 17 data points
# 20050207 has 2 data points
# 20050208 has 24 data points
# 20050209 has 0 data points
# Flux files created for E3-20050209
# 20050210 has 15 data points
# 20050211 has 35 data points
# 20050212 has 32 data points
# 20050213 has 1 data points
# 20050214 has 26 data points
# 20050215 has 42 data points
# 20050216 has 19 data points
# 20050217 has 4 data points
# 20050218 has 28 data points
# 20050219 has 1 data points
# 20050220 has 12 data points
# 20050221 has 38 data points
# 20050222 has 16 data points
# 20050223 has 5 data points
# Flux files created for E3-20050223
# 20050224 has 3 data points
# 20050225 has 37 data points
# 20050226 has 33 data points
# 20050227 has 27 data points
# 20050228 has 7 data points
# 20050301 has 2 data points
# 20050302 has 47 data points
# 20050303 has 40 data points
# 20050304 has 5 data points
# 20050305 has 12 data points
# 20050306 has 47 data points
# 20050307 has 18 data points
# 20050308 has 17 data points
# 20050309 has 27 data points
# Flux files created for E3-20050309
# 20050407 has 31 data points
# 20050408 has 19 data points
# 20050409 has 44 data points
# 20050410 has 38 data points
# 20050411 has 41 data points
# 20050412 has 15 data points
# 20050413 has 15 data points
# 20050414 has 27 data points
# 20050415 has 21 data points
# 20050416 has 41 data points
# 20050417 has 47 data points
# 20050418 has 48 data points
# 20050419 has 48 data points
# 20050420 has 48 data points
# Flux files created for E3-20050420
# 20050421 has 45 data points
# 20050422 has 5 data points
# 20050423 has 7 data points
# 20050424 has 9 data points
# 20050425 has 23 data points
# 20050426 has 6 data points
# 20050427 has 6 data points
# 20050428 has 21 data points
# 20050429 has 45 data points
# 20050430 has 1 data points
# 20050501 has 9 data points
# 20050502 has 1 data points
# 20050503 has 12 data points
# 20050504 has 26 data points
# Flux files created for E3-20050504
# 20050506 has 48 data points
# 20050507 has 48 data points
# 20050508 has 43 data points
# 20050509 has 30 data points
# 20050510 has 40 data points
# 20050511 has 48 data points
# 20050512 has 34 data points
# 20050513 has 17 data points
# 20050514 has 9 data points
# 20050515 has 16 data points
# 20050516 has 36 data points
# 20050517 has 48 data points
# 20050518 has 48 data points
# 20050519 has 39 data points
# Flux files created for E3-20050519
# 20050520 has 29 data points
# 20050521 has 28 data points
# 20050522 has 41 data points
# 20050523 has 22 data points
# 20050524 has 8 data points
# 20050525 has 17 data points
# 20050526 has 21 data points
# 20050527 has 24 data points
# 20050528 has 40 data points
# 20050529 has 28 data points
# 20050530 has 46 data points
# 20050531 has 30 data points
# 20050601 has 10 data points
# 20050602 has 21 data points
# Flux files created for E3-20050602
# 20050603 has 18 data points
# 20050604 has 30 data points
# 20050605 has 43 data points
# 20050606 has 46 data points
# 20050607 has 48 data points
# 20050608 has 48 data points
# 20050609 has 33 data points
# 20050610 has 35 data points
# 20050611 has 2 data points
# 20050612 has 18 data points
# 20050613 has 34 data points
# 20050614 has 4 data points
# 20050615 has 15 data points
# 20050616 has 27 data points
# Flux files created for E3-20050616
# 20050616 has 27 data points
# 20050617 has 5 data points
# 20050618 has 2 data points
# 20050619 has 21 data points
# 20050620 has 20 data points
# 20050621 has 25 data points
# 20050622 has 46 data points
# 20050623 has 46 data points
# 20050624 has 48 data points
# 20050625 has 48 data points
# 20050626 has 48 data points
# 20050627 has 48 data points
# 20050628 has 40 data points
# 20050629 has 48 data points
# Flux files created for E3-20050629
# 20050630 has 32 data points
# 20050701 has 2 data points
# Flux files created for E3-20050713
# 20050715 has 0 data points
# 20050716 has 31 data points
# 20050717 has 44 data points
# 20050718 has 30 data points
# 20050719 has 12 data points
# Flux files created for E3-20050727
# 20050728 has 28 data points
# 20050729 has 34 data points
# 20050730 has 32 data points
# 20050731 has 47 data points
# 20050801 has 46 data points
# 20050802 has 48 data points
# 20050803 has 48 data points
# 20050804 has 32 data points
# 20050805 has 37 data points
# 20050806 has 20 data points
# 20050807 has 30 data points
# 20050808 has 37 data points
# 20050809 has 41 data points
# 20050810 has 18 data points
# Flux files created for E3-20050810
# 20050811 has 44 data points
# 20050812 has 41 data points
# 20050813 has 23 data points
# 20050814 has 15 data points
# 20050815 has 19 data points
# 20050816 has 17 data points
# 20050817 has 23 data points
# 20050818 has 48 data points
# 20050819 has 42 data points
# 20050820 has 11 data points
# 20050821 has 18 data points
# 20050822 has 32 data points
# 20050823 has 2 data points
# 20050824 has 4 data points
# Flux files created for E3-20050824
# 20050825 has 9 data points
# 20050826 has 19 data points
# 20050827 has 17 data points
# 20050828 has 22 data points
# 20050829 has 21 data points
# 20050830 has 36 data points
# 20050831 has 46 data points
# 20050901 has 28 data points
# 20050902 has 8 data points
# 20050903 has 19 data points
# 20050904 has 48 data points
# 20050905 has 35 data points
# 20050906 has 37 data points
# 20050907 has 32 data points
# Flux files created for E3-20050907
# 20050908 has 44 data points
# 20050909 has 43 data points
# 20050910 has 40 data points
# 20050911 has 44 data points
# 20050912 has 48 data points
# 20050913 has 42 data points
# 20050914 has 19 data points
# 20050915 has 13 data points
# 20050916 has 19 data points
# 20050917 has 24 data points
# 20050918 has 28 data points
# 20050919 has 45 data points
# 20050920 has 16 data points
# 20050921 has 31 data points
# Flux files created for E3-20050921
# 20050923 has 13 data points
# 20050924 has 1 data points
# 20050925 has 21 data points
# 20050926 has 33 data points
# 20050927 has 27 data points
# 20050928 has 27 data points
# 20050929 has 5 data points
# 20050930 has 0 data points
# 20051001 has 0 data points
# 20051002 has 0 data points
# 20051003 has 0 data points
# 20051004 has 0 data points
# 20051005 has 0 data points
# 20051006 has 0 data points
# Flux files created for E3-20051006
# 20051006 has 0 data points
# 20051007 has 0 data points
# 20051008 has 0 data points
# 20051009 has 0 data points
# 20051010 has 0 data points
# 20051011 has 0 data points
# 20051012 has 0 data points
# 20051013 has 0 data points
# 20051014 has 0 data points
# 20051015 has 0 data points
# 20051016 has 0 data points
# 20051017 has 0 data points
# 20051018 has 0 data points
# 20051019 has 0 data points
# Flux files created for E3-20051019
# 20051020 has 0 data points
# 20051021 has 0 data points
# 20051022 has 0 data points
# 20051023 has 0 data points
# 20051024 has 0 data points
# 20051025 has 0 data points
# 20051026 has 0 data points
# 20051027 has 0 data points
# 20051028 has 0 data points
# 20051029 has 0 data points
# 20051030 has 0 data points
# 20051031 has 0 data points
# 20051101 has 0 data points
# 20051102 has 0 data points
# Flux files created for E3-20051102
# 20051103 has 0 data points
# 20051104 has 0 data points
# 20051105 has 0 data points
# 20051106 has 0 data points
# 20051107 has 0 data points
# 20051108 has 0 data points
# 20051109 has 0 data points
# 20051110 has 0 data points
# 20051111 has 0 data points
# 20051112 has 0 data points
# 20051113 has 0 data points
# 20051114 has 0 data points
# 20051115 has 0 data points
# 20051116 has 0 data points
# Flux files created for E3-20051116
# 20051117 has 0 data points
# 20051118 has 0 data points
# 20051119 has 0 data points
# 20051120 has 0 data points
# 20051121 has 0 data points
# 20051122 has 0 data points
# 20051123 has 0 data points
# 20051124 has 0 data points
# 20051125 has 0 data points
# 20051126 has 0 data points
# 20051127 has 0 data points
# 20051128 has 0 data points
# 20051129 has 0 data points
# 20051130 has 0 data points
# Flux files created for E3-20051130
# 20051201 has 0 data points
# 20051202 has 0 data points
# 20051203 has 0 data points
# 20051204 has 0 data points
# 20051205 has 0 data points
# 20051206 has 0 data points
# 20051207 has 0 data points
# 20051208 has 0 data points
# 20051209 has 0 data points
# 20051210 has 0 data points
# 20051211 has 0 data points
# 20051212 has 0 data points
# 20051213 has 0 data points
# 20051214 has 0 data points
# Flux files created for E3-20051214
# 20051215 has 0 data points
# 20051216 has 0 data points
# 20051217 has 0 data points
# 20051218 has 0 data points
# 20051219 has 0 data points
# 20051220 has 0 data points
# 20051221 has 0 data points
# 20051222 has 0 data points
# 20051223 has 0 data points
# 20051224 has 0 data points
# 20051225 has 0 data points
# 20051226 has 0 data points
# 20051227 has 0 data points
# 20051228 has 0 data points
# Flux files created for E3-20051228
# 20051229 has 0 data points
# 20051230 has 0 data points
# 20051231 has 0 data points
# 20060101 has 4 data points
# 20060102 has 9 data points
# 20060103 has 13 data points
# 20060104 has 1 data points
# 20060105 has 0 data points
# 20060106 has 0 data points
# 20060107 has 0 data points
# 20060108 has 0 data points
# 20060109 has 0 data points
# 20060110 has 0 data points
# 20060111 has 11 data points
# Flux files created for E3-20060111
# 20060113 has 0 data points
# 20060114 has 26 data points
# 20060115 has 16 data points
# 20060116 has 19 data points
# 20060117 has 0 data points
# 20060118 has 20 data points
# 20060119 has 0 data points
# 20060120 has 15 data points
# 20060121 has 16 data points
# 20060122 has 8 data points
# 20060123 has 30 data points
# 20060124 has 24 data points
# 20060125 has 7 data points
# 20060126 has 26 data points
# Flux files created for E3-20060126
# 20060126 has 26 data points
# 20060127 has 0 data points
# 20060128 has 3 data points
# 20060129 has 5 data points
# 20060130 has 0 data points
# 20060131 has 0 data points
# 20060201 has 0 data points
# 20060202 has 0 data points
# 20060203 has 0 data points
# 20060204 has 0 data points
# 20060205 has 0 data points
# 20060206 has 0 data points
# 20060207 has 0 data points
# 20060208 has 0 data points
# Flux files created for E3-20060208
# 20060727 has 20 data points
# 20060728 has 18 data points
# 20060729 has 42 data points
# 20060730 has 48 data points
# 20060731 has 48 data points
# 20060801 has 48 data points
# 20060802 has 48 data points
# 20060803 has 2 data points
# Flux files created for E3-20060809
# 20060810 has 38 data points
# 20060811 has 26 data points
# 20060812 has 16 data points
# 20060813 has 36 data points
# 20060814 has 28 data points
# 20060815 has 19 data points
# 20060816 has 9 data points
# 20060817 has 31 data points
# 20060818 has 36 data points
# 20060819 has 26 data points
# 20060820 has 29 data points
# 20060821 has 25 data points
# 20060822 has 21 data points
# 20060823 has 27 data points
# Flux files created for E3-20060823
# 20060824 has 48 data points
# 20060825 has 45 data points
# 20060826 has 21 data points
# 20060827 has 21 data points
# 20060828 has 6 data points
# 20060829 has 9 data points
# 20060830 has 13 data points
# 20060831 has 3 data points
# 20060901 has 8 data points
# 20060902 has 37 data points
# 20060903 has 27 data points
# 20060904 has 12 data points
# 20060905 has 16 data points
# 20060906 has 9 data points
# Flux files created for E3-20060906
# 20060907 has 26 data points
# 20060908 has 33 data points
# 20060909 has 14 data points
# 20060910 has 35 data points
# 20060911 has 7 data points
# 20060912 has 2 data points
# 20060913 has 0 data points
# 20060914 has 38 data points
# 20060915 has 48 data points
# 20060916 has 48 data points
# 20060917 has 19 data points
# 20060918 has 5 data points
# 20060919 has 1 data points
# 20060920 has 25 data points
# Flux files created for E3-20060920
# 20060921 has 32 data points
# 20060922 has 29 data points
# 20060923 has 1 data points
# 20060924 has 0 data points
# 20060925 has 13 data points
# 20060926 has 11 data points
# 20060927 has 23 data points
# 20060928 has 0 data points
# 20060929 has 35 data points
# 20060930 has 24 data points
# 20061001 has 37 data points
# 20061002 has 48 data points
# 20061003 has 48 data points
# 20061004 has 23 data points
# Flux files created for E3-20061004
# 20061005 has 26 data points
# 20061006 has 15 data points
# 20061007 has 42 data points
# 20061008 has 45 data points
# 20061009 has 36 data points
# 20061010 has 30 data points
# 20061011 has 6 data points
# 20061012 has 0 data points
# 20061013 has 10 data points
# 20061014 has 8 data points
# 20061015 has 19 data points
# 20061016 has 14 data points
# 20061017 has 27 data points
# 20061018 has 12 data points
# Flux files created for E3-20061018
# 20061019 has 7 data points
# 20061020 has 48 data points
# 20061021 has 28 data points
# 20061022 has 0 data points
# 20061023 has 24 data points
# 20061024 has 31 data points
# 20061025 has 29 data points
# 20061026 has 5 data points
# 20061027 has 10 data points
# 20061028 has 17 data points
# 20061029 has 46 data points
# 20061030 has 48 data points
# 20061031 has 31 data points
# 20061101 has 47 data points
# Flux files created for E3-20061101
# 20061102 has 17 data points
# 20061103 has 22 data points
# 20061104 has 48 data points
# 20061105 has 48 data points
# 20061106 has 21 data points
# 20061107 has 16 data points
# 20061108 has 48 data points
# 20061109 has 28 data points
# 20061110 has 15 data points
# 20061111 has 13 data points
# 20061112 has 48 data points
# 20061113 has 21 data points
# 20061114 has 9 data points
# 20061115 has 13 data points
# Flux files created for E3-20061115
# 20061116 has 4 data points
# 20061117 has 31 data points
# 20061118 has 6 data points
# 20061119 has 8 data points
# 20061120 has 24 data points
# 20061121 has 48 data points
# 20061122 has 48 data points
# 20061123 has 42 data points
# 20061124 has 39 data points
# 20061125 has 31 data points
# 20061126 has 48 data points
# 20061127 has 42 data points
# 20061128 has 43 data points
# 20061129 has 16 data points
# Flux files created for E3-20061129
# 20061130 has 9 data points
# 20061201 has 15 data points
# 20061202 has 42 data points
# 20061203 has 15 data points
# 20061204 has 48 data points
# 20061205 has 26 data points
# 20061206 has 15 data points
# 20061207 has 17 data points
# 20061208 has 46 data points
# 20061209 has 48 data points
# 20061210 has 48 data points
# 20061211 has 32 data points
# 20061212 has 28 data points
# 20061213 has 48 data points
# Flux files created for E3-20061213
# 20061214 has 39 data points
# 20061215 has 18 data points
# 20061216 has 41 data points
# 20061217 has 35 data points
# 20061218 has 45 data points
# 20061219 has 25 data points
# 20061220 has 2 data points
# 20061221 has 28 data points
# 20061222 has 21 data points
# 20061223 has 2 data points
# 20061224 has 18 data points
# 20061225 has 1 data points
# 20061226 has 18 data points
# 20061227 has 48 data points
# Flux files created for E3-20061227
# 20061228 has 48 data points
# 20061229 has 19 data points
# 20061230 has 0 data points
# 20061231 has 20 data points
# 20070101 has 1 data points
# 20070102 has 29 data points
# 20070103 has 48 data points
# 20070104 has 47 data points
# 20070105 has 14 data points
# 20070106 has 11 data points
# 20070107 has 10 data points
# 20070108 has 28 data points
# 20070109 has 0 data points
# 20070110 has 42 data points
# Flux files created for E3-20070110
# 20070111 has 48 data points
# 20070112 has 2 data points
# 20070113 has 3 data points
# 20070114 has 0 data points
# 20070115 has 0 data points
# 20070116 has 13 data points
# 20070117 has 34 data points
# 20070118 has 32 data points
# 20070119 has 7 data points
# 20070120 has 29 data points
# 20070121 has 4 data points
# 20070122 has 3 data points
# 20070123 has 14 data points
# 20070124 has 0 data points
# Flux files created for E3-20070124
# 20070208 has 31 data points
# 20070209 has 36 data points
# 20070210 has 34 data points
# 20070211 has 45 data points
# 20070212 has 18 data points
# 20070213 has 17 data points
# 20070214 has 24 data points
# 20070215 has 24 data points
# 20070216 has 37 data points
# 20070217 has 8 data points
# 20070218 has 31 data points
# 20070219 has 46 data points
# 20070220 has 35 data points
# 20070221 has 21 data points
# Flux files created for E3-20070221
# 20070221 has 21 data points
# 20070222 has 17 data points
# 20070223 has 19 data points
# 20070224 has 28 data points
# 20070225 has 7 data points
# 20070226 has 29 data points
# 20070227 has 9 data points
# 20070228 has 18 data points
# 20070301 has 15 data points
# 20070302 has 6 data points
# 20070303 has 0 data points
# 20070304 has 13 data points
# 20070305 has 32 data points
# 20070306 has 21 data points
# Flux files created for E3-20070306
# 20070308 has 35 data points
# 20070309 has 29 data points
# 20070310 has 21 data points
# 20070311 has 7 data points
# 20070312 has 30 data points
# 20070313 has 45 data points
# 20070314 has 45 data points
# 20070315 has 41 data points
# 20070316 has 32 data points
# 20070317 has 29 data points
# 20070318 has 12 data points
# 20070319 has 43 data points
# 20070320 has 8 data points
# 20070321 has 47 data points
# Flux files created for E3-20070321
# 20070322 has 46 data points
# 20070323 has 41 data points
# 20070324 has 47 data points
# 20070325 has 48 data points
# 20070326 has 46 data points
# 20070327 has 19 data points
# 20070328 has 39 data points
# 20070329 has 20 data points
# 20070330 has 13 data points
# 20070331 has 33 data points
# 20070401 has 12 data points
# 20070402 has 25 data points
# 20070403 has 28 data points
# 20070404 has 1 data points
# Flux files created for E3-20070404
# 20070503 has 10 data points
# 20070504 has 44 data points
# 20070505 has 48 data points
# 20070506 has 25 data points
# 20070507 has 19 data points
# 20070508 has 17 data points
# 20070509 has 23 data points
# 20070510 has 16 data points
# 20070511 has 30 data points
# 20070512 has 17 data points
# 20070513 has 27 data points
# 20070514 has 47 data points
# 20070515 has 23 data points
# 20070516 has 0 data points
# Flux files created for E3-20070516
# 20070517 has 13 data points
# 20070518 has 24 data points
# 20070519 has 45 data points
# 20070520 has 48 data points
# 20070521 has 48 data points
# 20070522 has 2 data points
# 20070523 has 48 data points
# 20070524 has 38 data points
# 20070525 has 25 data points
# 20070526 has 41 data points
# 20070527 has 37 data points
# 20070528 has 34 data points
# 20070529 has 45 data points
# 20070530 has 33 data points
# Flux files created for E3-20070530
# 20070531 has 21 data points
# 20070601 has 30 data points
# 20070602 has 20 data points
# 20070603 has 3 data points
# 20070604 has 2 data points
# 20070605 has 22 data points
# 20070606 has 35 data points
# 20070607 has 48 data points
# 20070608 has 12 data points
# 20070609 has 37 data points
# 20070610 has 23 data points
# 20070611 has 24 data points
# 20070612 has 11 data points
# 20070613 has 28 data points
# Flux files created for E3-20070613
# 20070613 has 28 data points
# 20070614 has 19 data points
# 20070615 has 6 data points
# 20070616 has 22 data points
# 20070617 has 47 data points
# 20070618 has 45 data points
# 20070619 has 4 data points
# 20070620 has 18 data points
# 20070621 has 47 data points
# 20070622 has 48 data points
# 20070623 has 34 data points
# 20070624 has 21 data points
# 20070625 has 48 data points
# 20070626 has 46 data points
# Flux files created for E3-20070626
# 20070628 has 7 data points
# 20070629 has 14 data points
# 20070630 has 2 data points
# 20070701 has 0 data points
# 20070702 has 3 data points
# 20070703 has 35 data points
# 20070704 has 41 data points
# 20070705 has 17 data points
# 20070706 has 19 data points
# 20070707 has 36 data points
# 20070708 has 47 data points
# 20070709 has 48 data points
# 20070710 has 19 data points
# 20070711 has 22 data points
# Flux files created for E3-20070711
# 20070713 has 30 data points
# 20070714 has 27 data points
# 20070715 has 33 data points
# 20070716 has 32 data points
# 20070717 has 47 data points
# 20070718 has 48 data points
# 20070719 has 48 data points
# 20070720 has 10 data points
# 20070721 has 0 data points
# 20070722 has 23 data points
# 20070723 has 30 data points
# 20070724 has 28 data points
# 20070725 has 47 data points
# 20070726 has 47 data points
# Flux files created for E3-20070726
# 20070726 has 47 data points
# 20070727 has 47 data points
# 20070728 has 28 data points
# 20070729 has 7 data points
# 20070730 has 5 data points
# 20070731 has 1 data points
# 20070801 has 17 data points
# 20070802 has 20 data points
# 20070803 has 30 data points
# 20070804 has 39 data points
# 20070805 has 48 data points
# 20070806 has 48 data points
# 20070807 has 48 data points
# 20070808 has 48 data points
# Flux files created for E3-20070808
# 20070809 has 33 data points
# 20070810 has 27 data points
# 20070811 has 42 data points
# 20070812 has 48 data points
# 20070813 has 35 data points
# 20070814 has 43 data points
# 20070815 has 45 data points
# 20070816 has 48 data points
# 20070817 has 19 data points
# 20070818 has 41 data points
# 20070819 has 40 data points
# 20070820 has 43 data points
# 20070821 has 44 data points
# 20070822 has 48 data points
# Flux files created for E3-20070822
# 20070823 has 48 data points
# 20070824 has 37 data points
# 20070825 has 12 data points
# 20070826 has 35 data points
# 20070827 has 48 data points
# 20070828 has 48 data points
# 20070829 has 34 data points
# 20070830 has 33 data points
# 20070831 has 19 data points
# 20070901 has 9 data points
# 20070902 has 24 data points
# 20070903 has 34 data points
# 20070904 has 40 data points
# 20070905 has 48 data points
# Flux files created for E3-20070905
# 20070906 has 46 data points
# 20070907 has 27 data points
# 20070908 has 16 data points
# 20070909 has 22 data points
# 20070910 has 33 data points
# 20070911 has 3 data points
# 20070912 has 29 data points
# 20070913 has 42 data points
# 20070914 has 42 data points
# 20070915 has 21 data points
# 20070916 has 31 data points
# 20070917 has 48 data points
# 20070918 has 45 data points
# 20070919 has 34 data points
# Flux files created for E3-20070919
# 20070920 has 34 data points
# 20070921 has 48 data points
# 20070922 has 25 data points
# 20070923 has 33 data points
# 20070924 has 48 data points
# 20070925 has 26 data points
# 20070926 has 18 data points
# 20070927 has 7 data points
# 20070928 has 33 data points
# 20070929 has 48 data points
# 20070930 has 45 data points
# 20071001 has 10 data points
# 20071002 has 41 data points
# 20071003 has 22 data points
# Flux files created for E3-20071003
# 20071004 has 40 data points
# 20071005 has 48 data points
# 20071006 has 48 data points
# 20071007 has 48 data points
# 20071008 has 22 data points
# 20071009 has 6 data points
# 20071010 has 35 data points
# 20071011 has 14 data points
# 20071012 has 27 data points
# 20071013 has 20 data points
# 20071014 has 48 data points
# 20071015 has 39 data points
# 20071016 has 40 data points
# 20071017 has 27 data points
# Flux files created for E3-20071017
# 20071018 has 23 data points
# 20071019 has 2 data points
# 20071020 has 48 data points
# 20071021 has 34 data points
# 20071022 has 10 data points
# 20071023 has 4 data points
# 20071024 has 15 data points
# 20071025 has 40 data points
# 20071026 has 20 data points
# 20071027 has 18 data points
# 20071028 has 34 data points
# 20071029 has 22 data points
# 20071030 has 48 data points
# 20071031 has 38 data points
# Flux files created for E3-20071031
# 20071018 has 23 data points
# 20071019 has 2 data points
# 20071020 has 48 data points
# 20071021 has 34 data points
# 20071022 has 10 data points
# 20071023 has 4 data points
# 20071024 has 15 data points
# 20071025 has 40 data points
# 20071026 has 20 data points
# 20071027 has 18 data points
# 20071028 has 34 data points
# 20071029 has 22 data points
# 20071030 has 48 data points
# 20071031 has 38 data points
# Flux files created for E3-20071031
# 20071101 has 16 data points
# 20071102 has 24 data points
# 20071103 has 24 data points
# 20071104 has 38 data points
# 20071105 has 30 data points
# 20071106 has 2 data points
# 20071107 has 28 data points
# 20071108 has 43 data points
# 20071109 has 25 data points
# 20071110 has 22 data points
# 20071111 has 46 data points
# 20071112 has 44 data points
# 20071113 has 34 data points
# 20071114 has 28 data points
# Flux files created for E3-20071114
# 20071227 has 17 data points
# 20071228 has 5 data points
# 20071229 has 10 data points
# 20071230 has 13 data points
# 20071231 has 13 data points
# 20080101 has 0 data points
# 20080102 has 0 data points
# 20080103 has 34 data points
# 20080104 has 43 data points
# 20080105 has 34 data points
# 20080106 has 46 data points
# 20080107 has 39 data points
# 20080108 has 7 data points
# 20080109 has 27 data points
# Flux files created for E3-20080109
# 20071204 has 13 data points
# 20071205 has 26 data points
# 20071206 has 4 data points
# 20071207 has 0 data points
# Flux files created for E3-20071212
# 20080110 has 18 data points
# 20080111 has 28 data points
# 20080112 has 13 data points
# 20080113 has 2 data points
# 20080114 has 13 data points
# 20080115 has 35 data points
# 20080116 has 33 data points
# 20080117 has 1 data points
# 20080118 has 30 data points
# 20080119 has 13 data points
# 20080120 has 14 data points
# 20080121 has 37 data points
# 20080122 has 1 data points
# 20080123 has 37 data points
# Flux files created for E3-20080123
# 20080124 has 2 data points
# 20080125 has 45 data points
# 20080126 has 19 data points
# 20080127 has 32 data points
# 20080128 has 48 data points
# 20080129 has 23 data points
# 20080130 has 21 data points
# 20080131 has 12 data points
# 20080201 has 22 data points
# 20080202 has 19 data points
# 20080203 has 5 data points
# 20080204 has 23 data points
# 20080205 has 19 data points
# 20080206 has 1 data points
# Flux files created for E3-20080206
# No data were found for E3-20080220
# No data were found for E3-20080305
# No data were found for E3-20080319
# 20080320 has 6 data points
# 20080321 has 27 data points
# 20080322 has 32 data points
# 20080323 has 4 data points
# 20080324 has 27 data points
# 20080325 has 43 data points
# 20080326 has 12 data points
# 20080327 has 0 data points
# 20080328 has 5 data points
# 20080329 has 12 data points
# 20080330 has 1 data points
# 20080331 has 17 data points
# 20080401 has 9 data points
# 20080402 has 30 data points
# Flux files created for E3-20080402
# 20080403 has 9 data points
# 20080404 has 21 data points
# 20080405 has 41 data points
# 20080406 has 39 data points
# 20080407 has 21 data points
# 20080408 has 7 data points
# 20080409 has 6 data points
# 20080410 has 20 data points
# 20080411 has 23 data points
# 20080412 has 0 data points
# 20080413 has 0 data points
# 20080414 has 19 data points
# 20080415 has 48 data points
# 20080416 has 48 data points
# Flux files created for E3-20080416
# 20080710 has 40 data points
# 20080711 has 48 data points
# 20080712 has 31 data points
# 20080713 has 13 data points
# 20080714 has 46 data points
# 20080715 has 42 data points
# 20080716 has 43 data points
# 20080717 has 48 data points
# 20080718 has 41 data points
# 20080719 has 35 data points
# 20080720 has 48 data points
# 20080721 has 48 data points
# 20080722 has 39 data points
# 20080723 has 16 data points
# Flux files created for E3-20080723
# 20080724 has 37 data points
# 20080725 has 35 data points
# 20080726 has 27 data points
# 20080727 has 42 data points
# 20080728 has 10 data points
# 20080729 has 23 data points
# 20080730 has 12 data points
# 20080731 has 22 data points
# 20080801 has 19 data points
# 20080802 has 33 data points
# 20080803 has 48 data points
# 20080804 has 48 data points
# 20080805 has 36 data points
# 20080806 has 19 data points
# Flux files created for E3-20080806
# 20080807 has 16 data points
# 20080808 has 15 data points
# 20080809 has 7 data points
# 20080810 has 1 data points
# 20080811 has 2 data points
# 20080812 has 17 data points
# 20080813 has 17 data points
# 20080814 has 25 data points
# 20080815 has 13 data points
# 20080816 has 21 data points
# 20080817 has 0 data points
# 20080818 has 19 data points
# Flux files created for E3-20080820
# 20080821 has 34 data points
# 20080822 has 48 data points
# 20080823 has 28 data points
# 20080824 has 31 data points
# 20080825 has 21 data points
# 20080826 has 7 data points
# 20080827 has 31 data points
# 20080828 has 48 data points
# 20080829 has 12 data points
# 20080830 has 2 data points
# 20080831 has 26 data points
# 20080901 has 44 data points
# 20080902 has 26 data points
# 20080903 has 25 data points
# Flux files created for E3-20080903
# 20080904 has 12 data points
# 20080905 has 9 data points
# 20080906 has 8 data points
# 20080907 has 8 data points
# 20080908 has 16 data points
# 20080909 has 27 data points
# 20080910 has 11 data points
# 20080911 has 30 data points
# 20080912 has 11 data points
# 20080913 has 12 data points
# 20080914 has 5 data points
# 20080915 has 9 data points
# 20080916 has 29 data points
# 20080917 has 32 data points
# Flux files created for E3-20080917
# 20080917 has 32 data points
# 20080918 has 26 data points
# 20080919 has 29 data points
# 20080920 has 8 data points
# 20080921 has 22 data points
# 20080922 has 40 data points
# 20080923 has 48 data points
# 20080924 has 35 data points
# 20080925 has 17 data points
# 20080926 has 33 data points
# 20080927 has 37 data points
# 20080928 has 30 data points
# 20080929 has 36 data points
# 20080930 has 3 data points
# Flux files created for E3-20080930
# 20081002 has 32 data points
# 20081003 has 30 data points
# 20081004 has 21 data points
# 20081005 has 48 data points
# 20081006 has 37 data points
# 20081007 has 21 data points
# 20081008 has 22 data points
# 20081009 has 27 data points
# 20081010 has 48 data points
# 20081011 has 48 data points
# 20081012 has 46 data points
# 20081013 has 38 data points
# 20081014 has 0 data points
# 20081015 has 10 data points
# Flux files created for E3-20081015
# 20081016 has 22 data points
# 20081017 has 25 data points
# 20081018 has 25 data points
# 20081019 has 48 data points
# 20081020 has 44 data points
# 20081021 has 1 data points
# 20081022 has 19 data points
# 20081023 has 48 data points
# 20081024 has 26 data points
# 20081025 has 28 data points
# 20081026 has 22 data points
# 20081027 has 0 data points
# 20081028 has 30 data points
# 20081029 has 44 data points
# Flux files created for E3-20081029
# 20081210 has 11 data points
# 20081211 has 25 data points
# 20081212 has 22 data points
# 20081213 has 48 data points
# 20081214 has 32 data points
# 20081215 has 8 data points
# 20081216 has 7 data points
# 20081217 has 0 data points
# 20081218 has 3 data points
# 20081219 has 6 data points
# 20081220 has 5 data points
# 20081221 has 0 data points
# 20081222 has 27 data points
# 20081223 has 32 data points
# Flux files created for E3-20081223
# 20081225 has 41 data points
# 20081226 has 48 data points
# 20081227 has 19 data points
# 20081228 has 44 data points
# 20081229 has 39 data points
# 20081230 has 26 data points
# 20081231 has 23 data points
# 20090101 has 42 data points
# 20090102 has 29 data points
# 20090103 has 16 data points
# 20090104 has 8 data points
# 20090105 has 36 data points
# 20090106 has 30 data points
# 20090107 has 16 data points
# Flux files created for E3-20090107
# 20090108 has 37 data points
# 20090109 has 46 data points
# 20090110 has 0 data points
# 20090111 has 22 data points
# 20090112 has 26 data points
# 20090113 has 14 data points
# 20090114 has 30 data points
# 20090115 has 44 data points
# 20090116 has 41 data points
# 20090117 has 31 data points
# 20090118 has 4 data points
# 20090119 has 9 data points
# 20090120 has 15 data points
# 20090121 has 33 data points
# Flux files created for E3-20090121
# 20090123 has 39 data points
# 20090124 has 43 data points
# 20090125 has 6 data points
# 20090126 has 18 data points
# 20090127 has 15 data points
# 20090128 has 22 data points
# 20090129 has 16 data points
# 20090130 has 19 data points
# 20090131 has 40 data points
# 20090201 has 44 data points
# 20090202 has 9 data points
# 20090203 has 40 data points
# 20090204 has 25 data points
# 20090205 has 48 data points
# Flux files created for E3-20090205
# 20090205 has 48 data points
# 20090206 has 48 data points
# 20090207 has 47 data points
# 20090208 has 22 data points
# 20090209 has 32 data points
# 20090210 has 48 data points
# 20090211 has 2 data points
# 20090212 has 33 data points
# 20090213 has 12 data points
# 20090214 has 32 data points
# 20090215 has 15 data points
# 20090216 has 37 data points
# 20090217 has 48 data points
# 20090218 has 12 data points
# Flux files created for E3-20090218
# 20090306 has 31 data points
# 20090307 has 45 data points
# 20090308 has 13 data points
# 20090309 has 17 data points
# 20090310 has 12 data points
# 20090311 has 31 data points
# 20090312 has 8 data points
# 20090313 has 15 data points
# 20090314 has 21 data points
# 20090315 has 38 data points
# 20090316 has 37 data points
# 20090317 has 47 data points
# 20090318 has 42 data points
# 20090319 has 26 data points
# Flux files created for E3-20090319
# 20090403 has 27 data points
# 20090404 has 18 data points
# 20090405 has 17 data points
# 20090406 has 0 data points
# 20090407 has 15 data points
# 20090408 has 23 data points
# 20090409 has 0 data points
# 20090410 has 18 data points
# 20090411 has 19 data points
# 20090412 has 0 data points
# 20090413 has 0 data points
# 20090414 has 12 data points
# 20090415 has 5 data points
# 20090416 has 4 data points
# Flux files created for E3-20090416
# 20090417 has 4 data points
# 20090418 has 11 data points
# 20090419 has 3 data points
# 20090420 has 10 data points
# 20090421 has 6 data points
# 20090422 has 26 data points
# 20090423 has 22 data points
# 20090424 has 48 data points
# 20090425 has 48 data points
# 20090426 has 45 data points
# 20090427 has 15 data points
# 20090428 has 32 data points
# 20090429 has 5 data points
# 20090430 has 36 data points
# Flux files created for E3-20090430
# 20090501 has 38 data points
# 20090502 has 19 data points
# 20090503 has 25 data points
# 20090504 has 32 data points
# 20090505 has 40 data points
# 20090506 has 31 data points
# 20090507 has 25 data points
# 20090508 has 19 data points
# 20090509 has 9 data points
# 20090510 has 25 data points
# 20090511 has 35 data points
# 20090512 has 37 data points
# 20090513 has 46 data points
# 20090514 has 21 data points
# Flux files created for E3-20090514
# 20090514 has 21 data points
# 20090515 has 36 data points
# 20090516 has 28 data points
# 20090517 has 41 data points
# 20090518 has 42 data points
# 20090519 has 48 data points
# 20090520 has 48 data points
# 20090521 has 47 data points
# 20090522 has 24 data points
# 20090523 has 12 data points
# 20090524 has 21 data points
# 20090525 has 21 data points
# 20090526 has 12 data points
# 20090527 has 21 data points
# Flux files created for E3-20090527
# 20090529 has 12 data points
# 20090530 has 31 data points
# 20090531 has 30 data points
# 20090601 has 48 data points
# 20090602 has 31 data points
# 20090603 has 41 data points
# 20090604 has 31 data points
# 20090605 has 37 data points
# 20090606 has 48 data points
# 20090607 has 46 data points
# 20090608 has 22 data points
# 20090609 has 11 data points
# 20090610 has 15 data points
# 20090611 has 25 data points
# Flux files created for E3-20090611
# 20090611 has 25 data points
# 20090612 has 21 data points
# 20090613 has 25 data points
# 20090614 has 19 data points
# 20090615 has 26 data points
# 20090616 has 27 data points
# 20090617 has 3 data points
# 20090618 has 48 data points
# 20090619 has 48 data points
# 20090620 has 38 data points
# 20090621 has 40 data points
# 20090622 has 48 data points
# 20090623 has 34 data points
# 20090624 has 31 data points
# Flux files created for E3-20090624
# 20090625 has 39 data points
# 20090626 has 22 data points
# 20090627 has 39 data points
# 20090628 has 13 data points
# 20090629 has 25 data points
# 20090630 has 14 data points
# 20090701 has 10 data points
# 20090702 has 18 data points
# 20090703 has 4 data points
# Flux files created for E3-20090708
# No data were found for E3-20090722
# No data were found for E3-20090805
# 20090806 has 22 data points
# 20090807 has 48 data points
# 20090808 has 48 data points
# 20090809 has 48 data points
# 20090810 has 37 data points
# 20090811 has 16 data points
# 20090812 has 37 data points
# 20090813 has 42 data points
# 20090814 has 35 data points
# 20090815 has 43 data points
# 20090816 has 44 data points
# 20090817 has 23 data points
# 20090818 has 19 data points
# 20090819 has 12 data points
# Flux files created for E3-20090819

# %% [markdown]
# ### Add 2-week average latent flux into the site dataframe

# %%
# latent-flux-biweekly-E3-20090819 is concatenated multi-day, latent-flux-E3-20090819 is just for that date

for ii in range(0,len(site_conditions)):
    date=pd.to_datetime(site_conditions.Date.values)[ii].date().strftime('%Y%m%d')
    ind=site_conditions.index[ii]
    if 'latent_flux_biweekly_{}_{}'.format(sitename,date) in globals():
        site_conditions.at[ind, 'Latent-Flux'] = float(globals()['latent_flux_biweekly_{}_{}'.format(sitename,date)].mean().values)

site_conditions['Latent-Flux'] = site_conditions['Latent-Flux'].astype(float)
# Out:
# C:\Users\sid.gupta\AppData\Local\Temp\ipykernel_37404\174082490.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   site_conditions['Latent-Flux'] = site_conditions['Latent-Flux'].astype(float)

# %% [markdown]
# ## Analysis Plots

# %%
flux_type_1='Latent-Flux'
flux_type_2='CO2-Flux'
# group_type=['rowCropsTypeEc','rowCropsConditionEc']
group_type='rctyp'
sns.set_theme('notebook')

# fig,ax=plt.subplots(2,1,figsize=(4.5,6))
cax=site_conditions.boxplot(column=flux_type_1,by=group_type,rot=90)
# site_conditions.boxplot(column=flux_type_2,by=group_type,rot=90,ax=ax[1])
# plt.suptitle('');ax[0].set_xlabel('');ax[0].set_xticklabels('');ax[1].set_xlabel('')
plt.suptitle('');plt.ylim([0,200])
plt.title('{} by {} \n {}'.format(site,group_type,flux_type_1))
dfg = site_conditions.groupby(group_type);counts = [[k,len(v)] for k, v in dfg];plt.legend(counts)
cax.set_xticklabels(['%s\n$n$=%d'%(k, len(v)) for k, v in dfg])

fig,ax=plt.subplots(2,2,figsize=(9,12))
crop_1=site_conditions.rctyp.value_counts().index[0]
site_croptype_1=site_conditions[site_conditions['rctyp']==crop_1]
site_croptype_1=site_croptype_1.drop(site_croptype_1[np.isnan(site_croptype_1['Latent-Flux'])].index)
site_croptype_1.plot('Date',flux_type_1,rot=90,ax=ax[0,0])
ax[0,0].set_ylabel(flux_type_1);ax[0,0].legend([crop_1]);ax[0,0].set_ylim([0,200]);

if len(site_conditions.rctyp.value_counts())>1:
    crop_2=site_conditions.rctyp.value_counts().index[1]
    site_croptype_2=site_conditions[site_conditions['rctyp']==crop_2]
    site_croptype_2=site_croptype_2.drop(site_croptype_2[np.isnan(site_croptype_2['Latent-Flux'])].index)
    site_croptype_2.plot('Date',flux_type_1,rot=90,ax=ax[0,1])
    ax[0,1].legend([crop_2]);ax[1,0].set_ylim([0,200])

if len(site_conditions.rctyp.value_counts())>2:
    crop_3=site_conditions.rctyp.value_counts().index[2]
    site_croptype_3=site_conditions[site_conditions['rctyp']==crop_3]
    site_croptype_3=site_croptype_3.drop(site_croptype_3[np.isnan(site_croptype_3['Latent-Flux'])].index)
    site_croptype_3.plot('Date',flux_type_1,rot=90,ax=ax[1,0])
    ax[1,0].legend([crop_3]);ax[1,0].set_ylim([0,200]);

if len(site_conditions.rctyp.value_counts())>3:
    crop_4=site_conditions.rctyp.value_counts().index[3]
    site_croptype_4=site_conditions[site_conditions['rctyp']==crop_4]
    site_croptype_4=site_croptype_4.drop(site_croptype_4[np.isnan(site_croptype_4['Latent-Flux'])].index)
    site_croptype_4.plot('Date',flux_type_1,rot=90,ax=ax[1,1])
    ax[1,1].legend([crop_4]);ax[1,1].set_ylim([0,200])

ax[0,0].set_title('{}: {} ({} day averages)'.format(site,flux_type_1,interval))

# fig,ax=plt.subplots(1,2,figsize=(6,3))
# site_croptype_1.plot('time',flux_type_2,rot=90,ax=ax[0])
# site_croptype_2.plot('time',flux_type_2,rot=90,ax=ax[1])
# ax[0].set_ylabel(flux_type_2)
# ax[0].legend([crop_1]);ax[1].legend([crop_2])
# plt.suptitle('{}: {} ({} day averages)'.format(site,flux_type_2,interval))
# ax[0].set_ylim([-20,20]);ax[1].set_ylim([-20,20])
# Out:
# Text(0.5, 1.0, 'E3 LeRoy: Latent-Flux (13 day averages)')

# %%
# del latent_flux_hourly_1
# del latent_flux_hourly_2
# del latent_flux_hourly_3
# del latent_flux_hourly_4
sns.set_theme('poster')

for k in range(0,len(site_croptype_1)): # len(site_croptype_1)
    if k==0:
        latent_flux_hourly_1=globals()['latent_flux_biweekly_{}_{}'.format(sitename,pd.to_datetime(site_croptype_1.Date.values)[k].strftime('%Y%m%d'))]
    else:
        latent_flux_hourly_1=xr.concat([latent_flux_hourly_1,globals()['latent_flux_biweekly_{}_{}'.format(sitename,pd.to_datetime(site_croptype_1.Date.values)[k].strftime('%Y%m%d'))]],'time')

fig,ax=plt.subplots(1,1,figsize=(17,5))
ax.plot(latent_flux_hourly_1.time,latent_flux_hourly_1)
ax.set_title('{}: {} (all data)'.format(sitename,flux_type_1,interval))
ax.set_ylim([-50,500]);ax.legend([crop_1])

if len(site_conditions.rctyp.value_counts())>1:
    for k in range(0,len(site_croptype_2)): # len(site_croptype_1)
        if k==0:
            latent_flux_hourly_2=globals()['latent_flux_biweekly_{}_{}'.format(sitename,pd.to_datetime(site_croptype_2.Date.values)[k].strftime('%Y%m%d'))]            
        else:
            latent_flux_hourly_2=xr.concat([latent_flux_hourly_2,globals()['latent_flux_biweekly_{}_{}'.format(sitename,pd.to_datetime(site_croptype_2.Date.values)[k].strftime('%Y%m%d'))]],'time')
    
    fig,ax=plt.subplots(1,1,figsize=(15,5))
    ax.plot(latent_flux_hourly_2.time,latent_flux_hourly_2)
    ax.set_title('{}: {} (all data)'.format(sitename,flux_type_1,interval))
    ax.set_ylim([-50,500]);ax.legend([crop_2])
            
if len(site_conditions.rctyp.value_counts())>2:
    if len(site_croptype_3)>1:
        for k in range(0,len(site_croptype_3)): # len(site_croptype_1)
            if k==0:
                latent_flux_hourly_3=globals()['latent_flux_biweekly_{}_{}'.format(sitename,pd.to_datetime(site_croptype_3.Date.values)[k].strftime('%Y%m%d'))]
            else:
                latent_flux_hourly_3=xr.concat([latent_flux_hourly_3,globals()['latent_flux_biweekly_{}_{}'.format(sitename,pd.to_datetime(site_croptype_3.Date.values)[k].strftime('%Y%m%d'))]],'time')

        fig,ax=plt.subplots(1,1,figsize=(15,5))
        ax.plot(latent_flux_hourly_3.time,latent_flux_hourly_3)
        ax.set_title('{}: {} (all data)'.format(sitename,flux_type_1,interval))
        ax.set_ylim([-50,500]);ax.legend([crop_3])  

if len(site_conditions.rctyp.value_counts())>3:
    if len(site_croptype_4)>1:
        for k in range(0,len(site_croptype_4)): # len(site_croptype_1)
            if k==0:
                latent_flux_hourly_4=globals()['latent_flux_biweekly_{}_{}'.format(sitename,pd.to_datetime(site_croptype_4.Date.values)[k].strftime('%Y%m%d'))]
            else:
                latent_flux_hourly_4=xr.concat([latent_flux_hourly_4,globals()['latent_flux_biweekly_{}_{}'.format(sitename,pd.to_datetime(site_croptype_4.Date.values)[k].strftime('%Y%m%d'))]],'time')

        fig,ax=plt.subplots(1,1,figsize=(15,5))
        ax.plot(latent_flux_hourly_4.time,latent_flux_hourly_4)
        ax.set_title('{}: {} (all data)'.format(sitename,flux_type_1,interval))
        ax.set_ylim([-50,500]);ax.legend([crop_4])

# %%
# plt.plot(latent_flux_hourly_1.time)
# plt.plot(latent_flux_hourly_1.time,latent_flux_hourly_1)
sns.set_theme('poster')

freq='30min' # 30min, daily, or monthly

fig,ax=plt.subplots(1,1,figsize=(15,6))
for k in range(0,len(list(latent_flux_hourly_1.groupby("time.year").groups))): # 
    globals()['year{}'.format(k)]=list(latent_flux_hourly_1.groupby("time.year").groups)[k]
    globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_1.groupby("time.year")[globals()['year{}'.format(k)]]
    globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
    globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
    if freq=='30min':
        plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
        plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_1))
    elif freq=='daily':
        plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
        plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_1))
    elif freq=='monthly':
        plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
        plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_1))    
    labels = [l for l in list(latent_flux_hourly_1.groupby("time.year").groups)]
    plt.legend(labels)
    plt.ylim([-250,500])
    

if len(site_conditions.rctyp.value_counts())>1:
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_2.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_2.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_2.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_2))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_2))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_2))    
        labels = [l for l in list(latent_flux_hourly_2.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])
        
if len(site_conditions.rctyp.value_counts())>2:        
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_3.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_3.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_3.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_3))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_3))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_3))    
        labels = [l for l in list(latent_flux_hourly_3.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])
        
if len(site_conditions.rctyp.value_counts())>3:        
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_4.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_4.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_4.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_4))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_4))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_4))    
        labels = [l for l in list(latent_flux_hourly_4.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])

# %%
# plt.plot(latent_flux_hourly_1.time)
# plt.plot(latent_flux_hourly_1.time,latent_flux_hourly_1)
sns.set_theme('poster')

freq='daily' # 30min, daily, or monthly

fig,ax=plt.subplots(1,1,figsize=(15,6))
for k in range(0,len(list(latent_flux_hourly_1.groupby("time.year").groups))): # 
    globals()['year{}'.format(k)]=list(latent_flux_hourly_1.groupby("time.year").groups)[k]
    globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_1.groupby("time.year")[globals()['year{}'.format(k)]]
    globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
    globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
    if freq=='30min':
        plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
        plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_1))
    elif freq=='daily':
        plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
        plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_1))
    elif freq=='monthly':
        plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
        plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_1))    
    labels = [l for l in list(latent_flux_hourly_1.groupby("time.year").groups)]
    plt.legend(labels)
    plt.ylim([-250,500])
    

if len(site_conditions.rctyp.value_counts())>1:
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_2.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_2.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_2.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_2))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_2))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_2))    
        labels = [l for l in list(latent_flux_hourly_2.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])
        
if len(site_conditions.rctyp.value_counts())>2:        
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_3.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_3.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_3.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_3))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_3))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_3))    
        labels = [l for l in list(latent_flux_hourly_3.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])
        
if len(site_conditions.rctyp.value_counts())>3:        
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_4.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_4.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_4.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_4))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_4))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_4))    
        labels = [l for l in list(latent_flux_hourly_4.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])

# %%
# plt.plot(latent_flux_hourly_1.time)
# plt.plot(latent_flux_hourly_1.time,latent_flux_hourly_1)
sns.set_theme('poster')

freq='monthly' # 30min, daily, or monthly

fig,ax=plt.subplots(1,1,figsize=(15,6))
for k in range(0,len(list(latent_flux_hourly_1.groupby("time.year").groups))): # 
    globals()['year{}'.format(k)]=list(latent_flux_hourly_1.groupby("time.year").groups)[k]
    globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_1.groupby("time.year")[globals()['year{}'.format(k)]]
    globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
    globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
    if freq=='30min':
        plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
        plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_1))
    elif freq=='daily':
        plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
        plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_1))
    elif freq=='monthly':
        plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
        plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_1))    
    labels = [l for l in list(latent_flux_hourly_1.groupby("time.year").groups)]
    plt.legend(labels)
    plt.ylim([-250,500])
    

if len(site_conditions.rctyp.value_counts())>1:
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_2.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_2.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_2.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_2))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_2))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_2))    
        labels = [l for l in list(latent_flux_hourly_2.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])
        
if len(site_conditions.rctyp.value_counts())>2:        
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_3.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_3.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_3.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_3))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_3))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_3))    
        labels = [l for l in list(latent_flux_hourly_3.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])
        
if len(site_conditions.rctyp.value_counts())>3:        
    fig,ax=plt.subplots(1,1,figsize=(15,6))
    for k in range(0,len(list(latent_flux_hourly_4.groupby("time.year").groups))): # 
        globals()['year{}'.format(k)]=list(latent_flux_hourly_4.groupby("time.year").groups)[k]
        globals()['latent_flux_year{}'.format(k)]=latent_flux_hourly_4.groupby("time.year")[globals()['year{}'.format(k)]]
        globals()['latent_flux_year{}_daily'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.dayofyear").mean()
        globals()['latent_flux_year{}_monthly'.format(k)]=globals()['latent_flux_year{}'.format(k)].groupby("time.month").mean()
        if freq=='30min':
            plt.plot(globals()['latent_flux_year{}'.format(k)]['time.dayofyear'],globals()['latent_flux_year{}'.format(k)])
            plt.xlabel('Day of Year');plt.title('30-min Latent Flux for {} - {}'.format(site,crop_4))
        elif freq=='daily':
            plt.plot(globals()['latent_flux_year{}_daily'.format(k)]['dayofyear'],globals()['latent_flux_year{}_daily'.format(k)])
            plt.xlabel('Day of Year');plt.title('Daily Latent Flux for {} - {}'.format(site,crop_4))
        elif freq=='monthly':
            plt.plot(globals()['latent_flux_year{}_monthly'.format(k)]['month'],globals()['latent_flux_year{}_monthly'.format(k)])
            plt.xlabel('Month');plt.title('Monthly Latent Flux for {} - {}'.format(site,crop_4))    
        labels = [l for l in list(latent_flux_hourly_4.groupby("time.year").groups)]
        plt.legend(labels)
        plt.ylim([-250,500])

# %%
flux_type_1='Latent-Flux'
group_type='ecvcon'
sns.set_theme('talk')

fig,ax=plt.subplots(1,2,figsize=(8,4))
site_croptype_1.boxplot(column=flux_type_1,by=group_type,rot=90,ax=ax[0])
plt.suptitle('')
ax[0].set_ylim([-100,200]);ax[0].legend([crop_1])

if len(site_conditions.rctyp.value_counts())>1:
    site_croptype_2.boxplot(column=flux_type_1,by=group_type,rot=90,ax=ax[1])
    plt.suptitle('')
    ax[1].set_ylim([-100,200]);ax[1].legend([crop_2])
    plt.suptitle('{}'.format(site));
    
fig,ax=plt.subplots(1,2,figsize=(8,4))
if len(site_conditions.rctyp.value_counts())>2:
    site_croptype_3.boxplot(column=flux_type_1,by=group_type,rot=90,ax=ax[0])
    plt.suptitle('')
    ax[0].set_ylim([-100,200]);ax[0].legend([crop_3])
    plt.suptitle('{}'.format(site));
    
if len(site_conditions.rctyp.value_counts())>3:
    site_croptype_4.boxplot(column=flux_type_1,by=group_type,rot=90,ax=ax[1])
    plt.suptitle('')
    ax[1].set_ylim([-100,200]);ax[1].legend([crop_4])
    plt.suptitle('{}'.format(site));
